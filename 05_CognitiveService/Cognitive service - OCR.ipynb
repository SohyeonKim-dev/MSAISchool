# %% [markdown]
# # Cognitive service - OCR

# %%
import requests

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from io import BytesIO
from PIL import Image

# %%
subscription_key = "{3502eb4d63164951a3b7b4571613e8a1}"
assert subscription_key

# %%
vision_base_url = "https://ksh-computervisionapi2.cognitiveservices.azure.com/vision/v2.0/"

# %%
ocr_url = vision_base_url + "ocr"

# %%
image_url = "https://thelitbuzz.com/staging/wp-content/uploads/2017/12/3e1f17f2c497ee51bc6c2bc86035008a-spiritual-quotes-universe-universe-quotes.jpg"


image = Image.open(BytesIO(requests.get(image_url).content))
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x800 at 0x1F8629EF730>

# %%
headers = {'Ocp-Apim-Subscription-Key' : subscription_key}
params = {'language' : 'unk', 'detectOrientation' : 'true'}
data = {'url' : image_url}

# %%
response = requests.post(ocr_url, headers = headers, params = params, json = data)
response.raise_for_status()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-43-3d4817b7221f> in <module>
#       1 response = requests.post(ocr_url, headers = headers, params = params, json = data)
# ----> 2 response.raise_for_status()
#
# C:\kimsohyeon\lib\site-packages\requests\models.py in raise_for_status(self)
#     939
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#     943     def close(self):
#
# HTTPError: 401 Client Error: PermissionDenied for url: https://ksh-computervisionapi2.cognitiveservices.azure.com/vision/v2.0/ocr?language=unk&detectOrientation=true

# %%
analysis = response.json()
analysis
# Out:
# {'error': {'code': '401',
#   'message': 'Access denied due to invalid subscription key or wrong API endpoint. Make sure to provide a valid key for an active subscription and use a correct regional API endpoint for your resource.'}}
