# %% [markdown]
# # Computer Vision - Face Detection

# %%
import json
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from PIL import Image, ImageDraw, ImageFont

# %%
subscription_key = "3e26ed0d61084997b5618c3435fd7ec1"
face_api_url = "https://face--api.cognitiveservices.azure.com/face/v1.0/detect"

# %%
image_url = "https://img.insight.co.kr/static/2020/04/21/700/hl45682pxq86dg2x67o1.jpg"
face_image = requests.get(image_url)
img = Image.open(BytesIO(face_image.content))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x540 at 0x2B4B4C063A0>

# %%
headers = {'Ocp-Apim-Subscription-Key' : subscription_key}

# %%
params = {
    'returnFaceId' : 'true',
    'returnFaceLandmarks' : 'false',
    'returnFaceAttributes' : 'age, gender'    
    # emotion 도 가능하다
}

# %%
data = {'url' : 'image_url'}

# %%
response = requests.post(face_api_url, params = params, headers = headers, json = data)
faces = response.json()

# %%
faces

#  {'error': {'code': 'InvalidURL', 'message': 'Invalid image URL.'}}   
# 왜... ㅠㅡㅠ
# Out:
# {'error': {'code': 'InvalidURL', 'message': 'Invalid image URL.'}}

# %%
# def CreateImage(faces):
